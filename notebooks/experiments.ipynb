# %%
from app import domain

# %%
file1 = "../resources/case_files/LB5001.pdf"
file2 = "../resources/case_files/MN414_0224.pdf"
file3 = "../resources/case_files/WEG-CESTARI-manual-iom-guia-consulta-rapida-50111652-pt-en-es-web.pdf"
file4 = "../resources/case_files/WEG-motores-eletricos-guia-de-especificacao-50032749-brochure-portuguese-web.pdf"

# %%
chunks = domain.load_file(file1)
# with open("output.txt", "w", encoding="utf-8") as f:
for doc in chunks:
    print(doc)
#         f.write(doc.page_content + "\n\n")
# chunks[0] = file_path
# print(len(chunks[0]))
# print(chunks[0])

# %%
domain.load_file(file2)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 19.1 (Windows)', 'creationdate': '2024-02-02T17:00:24-05:00', 'moddate': '2024-02-02T17:01:09-05:00', 'trapped': 'False', 'total_pages': 16, 'source': '../resources/case_files/MN414_0224.pdf'}, page_content='—\nAC Submersible Pump Motors\nInstallation and Operating Manual\n\nFebruary 2024\n\n4\n2\n0\n2\ny\nr\na\nu\nr\nb\ne\nF\n\n4\n1\n4\nN\nM\n\n—\n\x0cAny trademarks used in this manual are the property of their respective owners.\n\nImportant:\nBe sure to check www.baldor.com for the latest software, firmware and drivers for your ECM product. Also, you can\ndownload the latest version of this manual in Adobe Acrobat PDF format.\n\nNote: Baldor Electric Company, became ABB Motors and Mechanical, Inc. on March 1, 2018. Nameplates,\nDeclaration of Conformity and other collateral material may contain the company name of Baldor Electric Company\nand the brand names of Baldor-Dodge and Baldor-Reliance as 
# ...

# %% [markdown]
# # teste api

# %%
import requests

# %%
response = requests.get("http://localhost:8000/health")
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/challenge_tractian/.venv/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/challenge_tractian/.venv/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
response = requests.post(
    "http://localhost:8000/question",
    headers={"Content-Type": "application/json"},
    params={"question": "Qual é o propósito do documento?"}
)
print(response.json())
# Out:
# {'detail': [{'type': 'missing', 'loc': ['query', 'question'], 'msg': 'Field required', 'input': None}]}

# %%
url = "http://localhost:8000/documents"

with open("../resources/case_files/LB5001.pdf", "rb") as f1, open("../resources/case_files/MN414_0224.pdf", "rb") as f2:
    files = [
        ("files", ("doc1.pdf", f1, "application/pdf")),
        ("files", ("doc2.pdf", f2, "application/pdf")),
    ]

    response = requests.post(
        url, 
        files=files
    )

print(response.json())
# Out:
# {'detail': 'Missing boundary in multipart.'}

# %%
url = "http://localhost:8000/documents"
requests.delete(url)
# Out:
# <Response [200]>
